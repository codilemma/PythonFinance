# %%
from PersonalBudget import PersonalBudget

yaml_file = '../data/budget.yaml'
budget_start = '2022-09-22'
my_budget = PersonalBudget(budget_start,yaml_file)
my_budget.plot_budget()
# Out:
# ---------------------------------------------------------------------------
# UnknownTimeZoneError                      Traceback (most recent call last)
# <ipython-input-1-5d2a2e0f9343> in <module>
#       3 yaml_file = '../data/budget.yaml'
#       4 budget_start = '2022-09-22'
# ----> 5 my_budget = PersonalBudget(budget_start,yaml_file)
#       6 my_budget.plot_budget()
#
# c:\Users\kholthus\Documents\Python_WS\PythonFinance\PythonFinance\4_Budget\PersonalBudget.py in __init__(self, start_date, yaml_file)
#      20
#      21         # Get Start and End Date
# ---> 22         self.today = pd.Timestamp(start_date[0],start_date[1],start_date[2]).normalize()
#      23         self.end   = self.today + datetime.timedelta(days=365)
#      24
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# pandas\_libs\tslibs\timezones.pyx in pandas._libs.tslibs.timezones.maybe_get_tz()
#
# C:\Anaconda3\lib\site-packages\pytz\__init__.py in timezone(zone)
#     179                 fp.close()
#     180         else:
# --> 181             raise UnknownTimeZoneError(zone)
#     182
#     183     return _tzinfo_cache[zone]
#
# UnknownTimeZoneError: '2'

# %%
from PersonalBudget import PersonalBudget

yaml_file = '../data/budget.yaml'
budget_start = [2022,10,1]
my_budget = PersonalBudget(budget_start,yaml_file)
my_budget.plot_budget()
# Out:
# 2022-10-01 00:00:00
# 2023-10-01 00:00:00

# %%
from PersonalBudget import PersonalBudget

yaml_file = 'personal_budget.yaml'
budget_start = [2022,10,1]
my_budget = PersonalBudget(budget_start,yaml_file)
my_budget.plot_budget()
# Out:
# 2022-10-01 00:00:00
# 2023-10-01 00:00:00

# %%
from PersonalBudget import PersonalBudget

yaml_file = 'personal_budget.yaml'
budget_start = [2021,10,1]
my_budget = PersonalBudget(budget_start,yaml_file)
my_budget.plot_budget()

# %%
from PersonalBudget import PersonalBudget

yaml_file = 'personal_budget.yaml'
budget_start = [2021,10,1]
my_budget = PersonalBudget(budget_start,yaml_file)
my_budget.plot_budget()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9cda44c19f8c> in <module>
#       3 yaml_file = 'personal_budget.yaml'
#       4 budget_start = [2021,10,1]
# ----> 5 my_budget = PersonalBudget(budget_start,yaml_file)
#       6 my_budget.plot_budget()
#
# c:\Users\kholthus\Documents\Python_WS\PythonFinance\PythonFinance\4_Budget\PersonalBudget.py in __init__(self, start_date, yaml_file)
#      24
#      25         # Load Cash flow yaml file.
# ---> 26         with open(yaml_file) as file:
#      27             self.budget = yaml.load(file)
#      28
#
# FileNotFoundError: [Errno 2] No such file or directory: 'personal_budget.yaml'
