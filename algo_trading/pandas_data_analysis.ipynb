# %%
# The DataFrame Class
import pandas as pd

df = pd.DataFrame(
        [10,20,30,40],
        columns=['numbers'],
        index=['a','b','c','d'])
df
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40

# %%
# The 'index' attribute and 'Index' object
df.index
# Out:
# Index([&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;], dtype=&#39;object&#39;)

# %%
# The 'columns' attribute and 'Index' object.
df.columns
# Out:
# Index([&#39;numbers&#39;], dtype=&#39;object&#39;)

# %%
# Selects the value corresponding to index 'c'
df.loc['c']
# Out:
# numbers    30
# Name: c, dtype: int64

# %%
#'Selects the two values corresponding to indices 'a' and 'd'
df.loc[['a','d']]
# Out:
#    numbers
# a       10
# d       40

# %%
# Selects the second and third rows via the index positions.
df.iloc[1:3]
# Out:
#    numbers
# b       20
# c       30

# %%
# Calculates the sum of the single column
df.sum()
# Out:
# numbers    100
# dtype: int64

# %%
# Use the 'apply()' method to calculate squares in vectorized fashion
df.apply(lambda x: x **2)
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
# Applies vectorization directly as with 'ndarray' objects
df ** 2
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
# Unlike 'NumPy ndarray' ojbects, we have both dimensions.abs
# Create a new column based on a Data Frame object.abs
df['floats'] = (1.5, 2.5, 3.5, 4.5)
df
# Out:
#    numbers  floats
# a       10     1.5
# b       20     2.5
# c       30     3.5
# d       40     4.5

# %%
# Use whole DataFrame object to define a new column
df['names'] = pd.DataFrame(['Yves','Sandra','Lilli','Henry'],
                            index=['d','a','b','c'])

df
# Out:
#    numbers  floats   names
# a       10     1.5  Sandra
# b       20     2.5   Lilli
# c       30     3.5   Henry
# d       40     4.5    Yves

# %%
# 1 - Appends a new row via a 'dict' object;
#     Temporary operation during which index information gets lost.
df.append({'numbers': 100, 'floats': 5.75, 'names': 'Jil'},
            ignore_index=True)
# Out:
#    numbers  floats   names
# 0       10    1.50  Sandra
# 1       20    2.50   Lilli
# 2       30    3.50   Henry
# 3       40    4.50    Yves
# 4      100    5.75     Jil

# %%
# 2 - Appends row based on 'DataFrame' object with index info.
#     Original index is preserved
df = df.append(pd.DataFrame({'numbers': 100, 
                             'floats': 5.75,
                             'names':'Jil'},
                             index=['y']))

df
# Out:
#    numbers  floats   names
# a       10    1.50  Sandra
# b       20    2.50   Lilli
# c       30    3.50   Henry
# d       40    4.50    Yves
# y      100    5.75     Jil

# %%
# 3- Appends incomplete data row to 'DataFrame' object.  Fills with NaN 
#    vals
df = df.append(pd.DataFrame({'names': 'Liz'}, index=['z']), sort=False)
df
# Out:
#    numbers  floats   names
# a     10.0    1.50  Sandra
# b     20.0    2.50   Lilli
# c     30.0    3.50   Henry
# d     40.0    4.50    Yves
# y    100.0    5.75     Jil
# z      NaN     NaN     Liz

# %%
# 4 - Returns different 'dtypes' of the single columns.
df.dtypes
# Out:
# numbers    float64
# floats     float64
# names       object
# dtype: object

# %%
# 1- Calculates mean over the two specified columns
df[['numbers', 'floats']].mean()
# Out:
# numbers    40.00
# floats      3.55
# dtype: float64

# %%
# 2 - Calculates the standard deviation over specified columns
df[['numbers','floats']].std()
# Out:
# numbers    35.355339
# floats      1.662077
# dtype: float64

# %%
# Manage time series data:
import numpy as np

np.random.seed(100)
a = np.random.standard_normal((9,4))
a
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604],
#        [ 0.98132079,  0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349],
#        [-0.58359505,  0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825],
#        [ 1.61898166,  1.54160517, -0.25187914, -0.84243574],
#        [ 0.18451869,  0.9370822 ,  0.73100034,  1.36155613],
#        [-0.32623806,  0.05567601,  0.22239961, -1.443217  ],
#        [-0.75635231,  0.81645401,  0.75044476, -0.45594693]])

# %%
# convert ndarray object to DataFrame
df = pd.DataFrame(a)
df
# Out:
#           0         1         2         3
# 0 -1.749765  0.342680  1.153036 -0.252436
# 1  0.981321  0.514219  0.221180 -1.070043
# 2 -0.189496  0.255001 -0.458027  0.435163
# 3 -0.583595  0.816847  0.672721 -0.104411
# 4 -0.531280  1.029733 -0.438136 -1.118318
# 5  1.618982  1.541605 -0.251879 -0.842436
# 6  0.184519  0.937082  0.731000  1.361556
# 7 -0.326238  0.055676  0.222400 -1.443217
# 8 -0.756352  0.816454  0.750445 -0.455947

# %%
# Name the data frame columns
df.columns = ['No1','No2','No3','No4']
df
# Out:
#         No1       No2       No3       No4
# 0 -1.749765  0.342680  1.153036 -0.252436
# 1  0.981321  0.514219  0.221180 -1.070043
# 2 -0.189496  0.255001 -0.458027  0.435163
# 3 -0.583595  0.816847  0.672721 -0.104411
# 4 -0.531280  1.029733 -0.438136 -1.118318
# 5  1.618982  1.541605 -0.251879 -0.842436
# 6  0.184519  0.937082  0.731000  1.361556
# 7 -0.326238  0.055676  0.222400 -1.443217
# 8 -0.756352  0.816454  0.750445 -0.455947

# %%
df['No2'].mean()
# Out:
# 0.701033094145646

# %%
# Generate a DatetimeIndex with the date_range() function
dates = pd.date_range('2019-1-1', periods=9, freq='M')
dates
# Out:
# DatetimeIndex([&#39;2019-01-31&#39;, &#39;2019-02-28&#39;, &#39;2019-03-31&#39;, &#39;2019-04-30&#39;,
#                &#39;2019-05-31&#39;, &#39;2019-06-30&#39;, &#39;2019-07-31&#39;, &#39;2019-08-31&#39;,
#                &#39;2019-09-30&#39;],
#               dtype=&#39;datetime64[ns]&#39;, freq=&#39;M&#39;)

# %%
# change the index to dates
df.index = dates
df
# Out:
#                  No1       No2       No3       No4
# 2019-01-31 -1.749765  0.342680  1.153036 -0.252436
# 2019-02-28  0.981321  0.514219  0.221180 -1.070043
# 2019-03-31 -0.189496  0.255001 -0.458027  0.435163
# 2019-04-30 -0.583595  0.816847  0.672721 -0.104411
# 2019-05-31 -0.531280  1.029733 -0.438136 -1.118318
# 2019-06-30  1.618982  1.541605 -0.251879 -0.842436
# 2019-07-31  0.184519  0.937082  0.731000  1.361556
# 2019-08-31 -0.326238  0.055676  0.222400 -1.443217
# 2019-09-30 -0.756352  0.816454  0.750445 -0.455947

# %%
# Access all values as a list of lists.
df.values
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604],
#        [ 0.98132079,  0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349],
#        [-0.58359505,  0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825],
#        [ 1.61898166,  1.54160517, -0.25187914, -0.84243574],
#        [ 0.18451869,  0.9370822 ,  0.73100034,  1.36155613],
#        [-0.32623806,  0.05567601,  0.22239961, -1.443217  ],
#        [-0.75635231,  0.81645401,  0.75044476, -0.45594693]])

# %%
# Basic Analytics
df.info()
# Out:
# &lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# DatetimeIndex: 9 entries, 2019-01-31 to 2019-09-30
# Freq: M
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   No1     9 non-null      float64
#  1   No2     9 non-null      float64
#  2   No3     9 non-null      float64
#  3   No4     9 non-null      float64
# dtypes: float64(4)
# memory usage: 360.0 bytes

# %%
# Provides summary statistics per column for numerical data 
df.describe()
# Out:
#             No1       No2       No3       No4
# count  9.000000  9.000000  9.000000  9.000000
# mean  -0.150212  0.701033  0.289193 -0.387788
# std    0.988306  0.457685  0.579920  0.877532
# min   -1.749765  0.055676 -0.458027 -1.443217
# 25%   -0.583595  0.342680 -0.251879 -1.070043
# 50%   -0.326238  0.816454  0.222400 -0.455947
# 75%    0.184519  0.937082  0.731000 -0.104411
# max    1.618982  1.541605  1.153036  1.361556

# %%
# Collumn wise or Row wise analytics###################################

# Column-wise mean
df.sum()
# Out:
# No1   -1.351906
# No2    6.309298
# No3    2.602739
# No4   -3.490089
# dtype: float64

# %%
# Element-wise natural logarithim.
np.log(df)
# Out:
#                  No1       No2       No3       No4
# 2019-01-31       NaN -1.070957  0.142398       NaN
# 2019-02-28 -0.018856 -0.665106 -1.508780       NaN
# 2019-03-31       NaN -1.366486       NaN -0.832033
# 2019-04-30       NaN -0.202303 -0.396425       NaN
# 2019-05-31       NaN  0.029299       NaN       NaN
# 2019-06-30  0.481797  0.432824       NaN       NaN
# 2019-07-31 -1.690005 -0.064984 -0.313341  0.308628
# 2019-08-31       NaN -2.888206 -1.503279       NaN
# 2019-09-30       NaN -0.202785 -0.287089       NaN

# %%
# Element-Wise square root for the absolute values
# And column-wise mean values for the results.
np.sqrt(abs(df))
# Out:
#                  No1       No2       No3       No4
# 2019-01-31  1.322787  0.585389  1.073795  0.502430
# 2019-02-28  0.990616  0.717091  0.470297  1.034429
# 2019-03-31  0.435311  0.504977  0.676777  0.659669
# 2019-04-30  0.763934  0.903796  0.820196  0.323127
# 2019-05-31  0.728890  1.014757  0.661918  1.057506
# 2019-06-30  1.272392  1.241614  0.501876  0.917843
# 2019-07-31  0.429556  0.968030  0.854986  1.166857
# 2019-08-31  0.571173  0.235958  0.471593  1.201340
# 2019-09-30  0.869685  0.903578  0.866282  0.675238

# %%
# And column-wise mean values for the results.
np.sqrt(abs(df)).sum
# Out:
# &lt;bound method DataFrame.sum of                  No1       No2       No3       No4
# 2019-01-31  1.322787  0.585389  1.073795  0.502430
# 2019-02-28  0.990616  0.717091  0.470297  1.034429
# 2019-03-31  0.435311  0.504977  0.676777  0.659669
# 2019-04-30  0.763934  0.903796  0.820196  0.323127
# 2019-05-31  0.728890  1.014757  0.661918  1.057506
# 2019-06-30  1.272392  1.241614  0.501876  0.917843
# 2019-07-31  0.429556  0.968030  0.854986  1.166857
# 2019-08-31  0.571173  0.235958  0.471593  1.201340
# 2019-09-30  0.869685  0.903578  0.866282  0.675238&gt;

# %%
# A linear transform of the numerical data.
100 * df + 100
# Out:
#                    No1         No2         No3         No4
# 2019-01-31  -74.976547  134.268040  215.303580   74.756396
# 2019-02-28  198.132079  151.421884  122.117967   -7.004333
# 2019-03-31   81.050417  125.500144   54.197301  143.516349
# 2019-04-30   41.640495  181.684707  167.272081   89.558886
# 2019-05-31   46.871962  202.973269   56.186438  -11.831825
# 2019-06-30  261.898166  254.160517   74.812086   15.756426
# 2019-07-31  118.451869  193.708220  173.100034  236.155613
# 2019-08-31   67.376194  105.567601  122.239961  -44.321700
# 2019-09-30   24.364769  181.645401  175.044476   54.405307

# %%
####################################### Basic visualization.

# Customize ustomizing the plotting style.
from pylab import plt, mpl

plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'serif'

# Plot the cumulative sums of the four columns as a line plot.mpl
df.cumsum().plot(lw=2.0, figsize=(10,6))
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x24ea620b688&gt;
# &lt;Figure size 720x432 with 1 Axes&gt;

# %%
# Plot a bar plot
df.plot.bar(figsize=(10,6), rot=15)
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x24eabcd8b48&gt;
# &lt;Figure size 720x432 with 1 Axes&gt;

# %%
# The series class
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
S = pd.Series(np.linspace(0,15,7), name='series')
S
# Out:
# 0     0.0
# 1     2.5
# 2     5.0
# 3     7.5
# 4    10.0
# 5    12.5
# 6    15.0
# Name: series, dtype: float64

# %%
type(S)
# Out:
# pandas.core.series.Series

# %%
s = df['No1']
s
# Out:
# 2019-01-31   -1.749765
# 2019-02-28    0.981321
# 2019-03-31   -0.189496
# 2019-04-30   -0.583595
# 2019-05-31   -0.531280
# 2019-06-30    1.618982
# 2019-07-31    0.184519
# 2019-08-31   -0.326238
# 2019-09-30   -0.756352
# Freq: M, Name: No1, dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.mean()
# Out:
# -0.15021177307319458

# %%
s.plot(lw=2.0, figsize=(10, 6))
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x24eab4fddc8&gt;
# &lt;Figure size 720x432 with 1 Axes&gt;

# %%
## Group By Operations

# Add Quarter column
df['Quarter'] = ['Q1','Q1','Q1','Q2','Q2','Q2','Q3','Q3','Q3']
df
# Out:
#                  No1       No2       No3       No4 Quarter
# 2019-01-31 -1.749765  0.342680  1.153036 -0.252436      Q1
# 2019-02-28  0.981321  0.514219  0.221180 -1.070043      Q1
# 2019-03-31 -0.189496  0.255001 -0.458027  0.435163      Q1
# 2019-04-30 -0.583595  0.816847  0.672721 -0.104411      Q2
# 2019-05-31 -0.531280  1.029733 -0.438136 -1.118318      Q2
# 2019-06-30  1.618982  1.541605 -0.251879 -0.842436      Q2
# 2019-07-31  0.184519  0.937082  0.731000  1.361556      Q3
# 2019-08-31 -0.326238  0.055676  0.222400 -1.443217      Q3
# 2019-09-30 -0.756352  0.816454  0.750445 -0.455947      Q3

# %%
# Group the 'Quarter' column and output statistics for the single groups
groups = df.groupby('Quarter')
groups.size()
# Out:
# Quarter
# Q1    3
# Q2    3
# Q3    3
# dtype: int64

# %%
groups.mean()
# Out:
#               No1       No2       No3       No4
# Quarter
# Q1      -0.319314  0.370634  0.305396 -0.295772
# Q2       0.168035  1.129395 -0.005765 -0.688388
# Q3      -0.299357  0.603071  0.567948 -0.179203

# %%
groups.max()
# Out:
#               No1       No2       No3       No4
# Quarter
# Q1       0.981321  0.514219  1.153036  0.435163
# Q2       1.618982  1.541605  0.672721 -0.104411
# Q3       0.184519  0.937082  0.750445  1.361556

# %%
groups.aggregate([min,max]).round(2)
# Out:
#           No1         No2         No3         No4
#           min   max   min   max   min   max   min   max
# Quarter
# Q1      -1.75  0.98  0.26  0.51 -0.46  1.15 -1.07  0.44
# Q2      -0.58  1.62  0.82  1.54 -0.44  0.67 -1.12 -0.10
# Q3      -0.76  0.18  0.06  0.94  0.22  0.75 -1.44  1.36

# %%
# Grouping with multiple columns - weather month is odd or even
df['Odd_Even'] = ['Odd','Even','Odd','Even','Odd','Even','Odd','Even','Odd']

groups = df.groupby(['Quarter','Odd_Even'])
groups.size()
# Out:
# Quarter  Odd_Even
# Q1       Even        1
#          Odd         2
# Q2       Even        2
#          Odd         1
# Q3       Even        1
#          Odd         2
# dtype: int64

# %%
groups[['No1','No4']].aggregate([sum,np.mean])
# Out:
#                        No1                 No4
#                        sum      mean       sum      mean
# Quarter Odd_Even
# Q1      Even      0.981321  0.981321 -1.070043 -1.070043
#         Odd      -1.939261 -0.969631  0.182727  0.091364
# Q2      Even      1.035387  0.517693 -0.946847 -0.473423
#         Odd      -0.531280 -0.531280 -1.118318 -1.118318
# Q3      Even     -0.326238 -0.326238 -1.443217 -1.443217
#         Odd      -0.571834 -0.285917  0.905609  0.452805

# %%
df[['No1','No4']].aggregate([min,max]).round(2)
# Out:
#       No1   No4
# min -1.75 -1.44
# max  1.62  1.36

# %%
## Complex Selection

# 1)
data = np.random.standard_normal((10,2))

# 2) 
df = pd.DataFrame(data,columns=['x','y'])
df.info()
# Out:
# &lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       10 non-null     float64
#  1   y       10 non-null     float64
# dtypes: float64(2)
# memory usage: 288.0 bytes

# %%
# 3 -
